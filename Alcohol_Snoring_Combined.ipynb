# %% [markdown]
# <a href="https://colab.research.google.com/github/richardsons5/skylinemath200/blob/main/Alcohol_Snoring_Combined.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # __ : Is there an association between if you have drinken alcohol and if you snore/stop breathing in your sleep?
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1:: ![Screen Shot 2023-05-01 at 8.32.27 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['H4TO33'].value_counts()
# Out:
# 1    4087
#      1390
# 0    1001
# 6      15
# 8      11
# Name: H4TO33, dtype: int64

# %%
df['Drink_Alcohol'] = df['H4TO33']
df['Drink_Alcohol'].value_counts()
# Out:
# 1    4087
#      1390
# 0    1001
# 6      15
# 8      11
# Name: Drink_Alcohol, dtype: int64

# %%
df['Drink_Alcohol'].replace(['0','1','7'] , ['NO','YES','NO'] , inplace = True)
df['Drink_Alcohol'].value_counts()
# Out:
# YES    4087
# NO     1001
# Name: Drink_Alcohol, dtype: int64

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
#Graphs and tables or statistics
rp.summary_cat(df['Drink_Alcohol'])
# Out:
#         Variable Outcome  Count  Percent
# 0  Drink_Alcohol     YES   4087    80.33
# 1                     NO   1001    19.67

# %%
explode = (0.1, 0.01)
df['Drink_Alcohol'].value_counts().plot(kind ='pie', autopct='%1.1f%%',  explode=explode, shadow=True, startangle=90, colors=['green', 'red'])
plt.legend(loc ="lower right")

# %%
plt.xlabel("Amount of Limitations")
plt.ylabel("Percent")
plt.title("Have you had a drink of beer, wine, or liquor more than two or three times?")
df['Drink_Alcohol'].value_counts(normalize = True).plot(kind ='barh', color = 'blue', width = 0.2, alpha = 0.5, grid = True)
# Out:
# <Axes: title={'center': 'Have you had a drink of beer, wine, or liquor more than two or three times?'}, ylabel='Percent'>

# %% [markdown]
# Codebook 2: ![Screen Shot 2023-05-01 at 8.35.33 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['H4SP7'].value_counts()
# Out:
# 0    2595
# 1    2458
#      1390
# 5      46
# 8      15
# Name: H4SP7, dtype: int64

# %%
df['SNORING'] = df['H4SP7']
df['SNORING'].value_counts()
# Out:
# 0    2595
# 1    2458
#      1390
# 5      46
# 8      15
# Name: SNORING, dtype: int64

# %%
df['SNORING'] = df['SNORING'].loc[ df['SNORING'] !='5'] 
df['SNORING'] = df['SNORING'].loc[ df['SNORING'] !='8'] 
df['SNORING'] = df['SNORING'].loc[ df['SNORING'] !=' '] 
df['SNORING'].value_counts()
# Out:
# NO     2595
# YES    2458
# Name: SNORING, dtype: int64

# %%
#Graphs and tables or statistics
rp.summary_cat(df['SNORING'])
# Out:
#   Variable Outcome  Count  Percent
# 0  SNORING      NO   2595    51.36
# 1              YES   2458    48.64

# %%
explode = (0.1, 0.01)
df['SNORING'].value_counts().plot(kind ='pie', autopct='%1.1f%%',  explode=explode, shadow=True, startangle=90, colors=['blue', 'yellow'])
plt.legend(loc ="lower right")

# %%
plt.xlabel("Amount of Limitations")
plt.ylabel("Percent")
plt.title("Based on what you have noticed or what others have told you, are there times when you snore or you stop breathing during your sleep?")
df['SNORING'].value_counts(normalize = True).plot(kind ='barh', color = 'red', width = 0.2, alpha = 0.5, grid = True)
# Out:
# <Axes: title={'center': 'Based on what you have noticed or what others have told you, are there times when you snore or you stop breathing during your sleep?'}, ylabel='Percent'>
